# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Helly Patel**
#
# To be more creative and open.

# %% [markdown]
# *I am interested in Data Science because it get some conclusion about the data. To understand the story of Data.*

# %% [markdown]
# ### The below code find Positive,Negative or Zero Number

# %%
def typeOfNumber(n):
    if n>0:
        print('The Number is Positive Number')
    elif n<0:
        print('The Number is Negative Number')
    else:
        print('The Number is Zero')
    
    
typeOfNumber(10)
# Out:
# The Number is Positive Number

# %% [markdown]
# ***
#
# This is Horizontal Line.
#
# ***
# This is Bulleted List
#
# * Number 1
# * Number 2
# * Number 3
#
# This is Numbered List
#
# 1. Number 1
# 2. Number 2
# 3. Number 3
#
# `Here Some COde`

# %%
# Out:
#   File "/tmp/wsuser/ipykernel_164/3031252438.py", line 1
#     ` Here Some Code`
#     ^
# SyntaxError: invalid syntax
